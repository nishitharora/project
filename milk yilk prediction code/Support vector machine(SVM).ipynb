# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
#data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")


# print(data1)
# print(data2)

from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)

data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

from sklearn.model_selection import train_test_split
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Create and train the Support Vector Regression model
svr = SVR(kernel='rbf')
svr.fit(X2_train, Y2_train)

# Make predictions on the test set
y2_pred = svr.predict(X2_test)

# Calculate Mean Squared Error and R-squared
mse = mean_squared_error(Y2_test, y2_pred)
r2 = r2_score(Y2_test, y2_pred)
print(f'Mean Squared Error: {mse}')
print('R-squared:', r2)

plt.scatter(Y2_test, y2_pred, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions')
plt.show()
# Out:
# Mean Squared Error: 2745.350339670563
# R-squared: 0.2062228917184331

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
#data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")


# print(data1)
# print(data2)

from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)

data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

from sklearn.model_selection import train_test_split
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Create and train the Support Vector Regression model
svr = SVR(kernel='poly')
svr.fit(X2_train, Y2_train)

# Make predictions on the test set
y2_pred = svr.predict(X2_test)

# Calculate Mean Squared Error and R-squared
mse = mean_squared_error(Y2_test, y2_pred)
r2 = r2_score(Y2_test, y2_pred)
print(f'Mean Squared Error: {mse}')
print('R-squared:', r2)

plt.scatter(Y2_test, y2_pred, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions')
plt.show()
# Out:
# Mean Squared Error: 2696.46370129785
# R-squared: 0.22035773413922055

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
#data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")


# print(data1)
# print(data2)

from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)

data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

from sklearn.model_selection import train_test_split
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Create and train the Support Vector Regression model
svr = SVR(kernel='linear')
svr.fit(X2_train, Y2_train)

# Make predictions on the test set
y2_pred = svr.predict(X2_test)

# Calculate Mean Squared Error and R-squared
mse = mean_squared_error(Y2_test, y2_pred)
r2 = r2_score(Y2_test, y2_pred)
print(f'Mean Squared Error: {mse}')
print('R-squared:', r2)

plt.scatter(Y2_test, y2_pred, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions')
plt.show()
# Out:
# Mean Squared Error: 1187.8280475343984
# R-squared: 0.6565572345783972

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
# data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# Encoding categorical data
encoder = OneHotEncoder()
encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)
data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

# Prepare the data for SVR
data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

# Split the dataset into training and testing sets
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Feature scaling
scaler = StandardScaler()
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.transform(X2_test)


# Optimized SVR
optimized_svr = SVR(kernel='rbf', C=100, gamma=0.01, epsilon=0.1)
optimized_svr.fit(X2_train_scaled, Y2_train)

# Make predictions on the test set
y2_pred_optimized = optimized_svr.predict(X2_test_scaled)

# Calculate Mean Squared Error and R-squared for the optimized model
mse_optimized = mean_squared_error(Y2_test, y2_pred_optimized)
r2_optimized = r2_score(Y2_test, y2_pred_optimized)
print(f'Optimized Model - Mean Squared Error: {mse_optimized}')
print('Optimized Model - R-squared:', r2_optimized)

# Visualize Predictions
plt.scatter(Y2_test, y2_pred_optimized, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions (Optimized SVR)')
plt.show()
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5] END ......C=0.1, epsilon=0.1, gamma=1;, score=-0.151 total time=   5.2s
# [CV 2/5] END ......C=0.1, epsilon=0.1, gamma=1;, score=-0.140 total time=   5.0s
# [CV 3/5] END ......C=0.1, epsilon=0.1, gamma=1;, score=-0.128 total time=   5.3s
# [CV 4/5] END ......C=0.1, epsilon=0.1, gamma=1;, score=-0.131 total time=   5.4s
# [CV 5/5] END ......C=0.1, epsilon=0.1, gamma=1;, score=-0.124 total time=   4.7s
# [CV 1/5] END ....C=0.1, epsilon=0.1, gamma=0.1;, score=-0.135 total time=   4.0s
# [CV 2/5] END ....C=0.1, epsilon=0.1, gamma=0.1;, score=-0.125 total time=   4.4s
# [CV 3/5] END ....C=0.1, epsilon=0.1, gamma=0.1;, score=-0.118 total time=   4.1s
# [CV 4/5] END ....C=0.1, epsilon=0.1, gamma=0.1;, score=-0.119 total time=   3.5s
# [CV 5/5] END ....C=0.1, epsilon=0.1, gamma=0.1;, score=-0.114 total time=   4.3s
# [CV 1/5] END ...C=0.1, epsilon=0.1, gamma=0.01;, score=-0.062 total time=   4.2s
# [CV 2/5] END ...C=0.1, epsilon=0.1, gamma=0.01;, score=-0.050 total time=   4.2s
# [CV 3/5] END ...C=0.1, epsilon=0.1, gamma=0.01;, score=-0.044 total time=   4.2s
# [CV 4/5] END ...C=0.1, epsilon=0.1, gamma=0.01;, score=-0.049 total time=   4.2s
# [CV 5/5] END ...C=0.1, epsilon=0.1, gamma=0.01;, score=-0.039 total time=   4.1s
# [CV 1/5] END ..C=0.1, epsilon=0.1, gamma=0.001;, score=-0.142 total time=   4.1s
# [CV 2/5] END ..C=0.1, epsilon=0.1, gamma=0.001;, score=-0.133 total time=   3.5s
# [CV 3/5] END ..C=0.1, epsilon=0.1, gamma=0.001;, score=-0.120 total time=   4.0s
# [CV 4/5] END ..C=0.1, epsilon=0.1, gamma=0.001;, score=-0.123 total time=   4.0s
# [CV 5/5] END ..C=0.1, epsilon=0.1, gamma=0.001;, score=-0.117 total time=   4.0s
# [CV 1/5] END ......C=0.1, epsilon=0.2, gamma=1;, score=-0.150 total time=   4.8s
# [CV 2/5] END ......C=0.1, epsilon=0.2, gamma=1;, score=-0.140 total time=   5.2s
# [CV 3/5] END ......C=0.1, epsilon=0.2, gamma=1;, score=-0.127 total time=   5.2s
# [CV 4/5] END ......C=0.1, epsilon=0.2, gamma=1;, score=-0.131 total time=   4.7s
# [CV 2/5] END .......C=100, epsilon=0.4, gamma=1;, score=0.460 total time=  12.2s
# [CV 3/5] END .......C=100, epsilon=0.4, gamma=1;, score=0.498 total time=   9.6s
# [CV 4/5] END .......C=100, epsilon=0.4, gamma=1;, score=0.468 total time=  10.2s
# [CV 5/5] END .......C=100, epsilon=0.4, gamma=1;, score=0.487 total time=  10.5s
# [CV 1/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.675 total time=   5.2s
# [CV 2/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.621 total time=   5.2s
# [CV 3/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.691 total time=   4.4s
# [CV 4/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.681 total time=   4.3s
# [CV 5/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.668 total time=   4.2s
# [CV 1/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.730 total time=   4.0s
# [CV 2/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.653 total time=   3.9s
# [CV 3/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.744 total time=   4.4s
# [CV 4/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.694 total time=   3.9s
# [CV 5/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.711 total time=   3.7s
# [CV 1/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.691 total time=   3.6s
# [CV 2/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.632 total time=   4.0s
# [CV 3/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.709 total time=   3.9s
# [CV 4/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.668 total time=   3.7s
# [CV 5/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.695 total time=   3.7s
# {'C': 100, 'epsilon': 0.3, 'gamma': 0.01}
# Optimized Model - Mean Squared Error: 1015.1699706101471
# Optimized Model - R-squared: 0.7064787426067076

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
# data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# Encoding categorical data
encoder = OneHotEncoder()
encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)
data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

# Prepare the data for SVR
data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

# Split the dataset into training and testing sets
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Feature scaling
scaler = StandardScaler()
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.transform(X2_test)
# Optimized SVR
optimized_svr = SVR(kernel='linear', C=100, gamma=0.01, epsilon=0.1)
optimized_svr.fit(X2_train_scaled, Y2_train)

# Make predictions on the test set
y2_pred_optimized = optimized_svr.predict(X2_test_scaled)

# Calculate Mean Squared Error and R-squared for the optimized model
mse_optimized = mean_squared_error(Y2_test, y2_pred_optimized)
r2_optimized = r2_score(Y2_test, y2_pred_optimized)
print(f'Optimized Model - Mean Squared Error: {mse_optimized}')
print('Optimized Model - R-squared:', r2_optimized)

# Visualize Predictions
plt.scatter(Y2_test, y2_pred_optimized, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions (Optimized SVR)')
plt.show()
# Out:
# Optimized Model - Mean Squared Error: 1188.556364138133
# Optimized Model - R-squared: 0.6563466526940848

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# Encoding categorical data
encoder = OneHotEncoder()
encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)
data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

# Prepare the data for SVR
data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

# Split the dataset into training and testing sets
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Feature scaling
scaler = StandardScaler()
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.transform(X2_test)

# Hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'epsilon': [0.1, 0.2, 0.3, 0.4]}
grid = GridSearchCV(SVR(kernel='rbf'), param_grid, refit=True, verbose=3)
grid.fit(X2_train_scaled, Y2_train)
print(grid.best_params_)

# Optimized SVR
optimized_svr = SVR(kernel='rbf', C=100, gamma=0.01, epsilon=0.1)
optimized_svr.fit(X2_train_scaled, Y2_train)

# Make predictions on the test set
y2_pred_optimized = optimized_svr.predict(X2_test_scaled)

# Calculate Mean Squared Error and R-squared for the optimized model
mse_optimized = mean_squared_error(Y2_test, y2_pred_optimized)
r2_optimized = r2_score(Y2_test, y2_pred_optimized)
print(f'Optimized Model - Mean Squared Error: {mse_optimized}')
print('Optimized Model - R-squared:', r2_optimized)

# Visualize Predictions
plt.scatter(Y2_test, y2_pred_optimized, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('
# [CV 2/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.621 total time=   3.8s
# [CV 3/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.691 total time=   3.0s
# [CV 4/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.681 total time=   4.2s
# [CV 5/5] END .....C=100, epsilon=0.4, gamma=0.1;, score=0.668 total time=   4.1s
# [CV 1/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.730 total time=   3.4s
# [CV 2/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.653 total time=   3.4s
# [CV 3/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.744 total time=   2.6s
# [CV 4/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.694 total time=   3.4s
# [CV 5/5] END ....C=100, epsilon=0.4, gamma=0.01;, score=0.711 total time=   3.4s
# [CV 1/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.691 total time=   3.2s
# [CV 2/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.632 total time=   3.3s
# [CV 3/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.709 total time=   2.5s
# [CV 4/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.668 total time=   3.3s
# [CV 5/5] END ...C=100, epsilon=0.4, gamma=0.001;, score=0.695 total time=   3.3s
# {'C': 100, 'epsilon': 0.3, 'gamma': 0.01}
# Optimized Model - Mean Squared Error: 1015.1699706101471
# Optimized Model - R-squared: 0.7064787426067076

# %%
# Import required libraries
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
# data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# print(data1)
# print(data2)

from sklearn.preprocessing import OneHotEncoder
encoder = OneHotEncoder()

encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

Y2_ = data2['Farm Milk Production per \nDay']
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder', 'Farm Milk Production per \nDay'], axis=1)

data2 = data2.join(encoded_data2)
data2 = data2.join(Y2_)

data2 = data2.to_numpy()
X2 = data2[:, :-1]
Y2 = data2[:, -1]

from sklearn.model_selection import train_test_split
X2_train, X2_test, Y2_train, Y2_test = train_test_split(X2, Y2, test_size=0.1, random_state=0)

# Feature scaling
scaler = StandardScaler()
X2_train_scaled = scaler.fit_transform(X2_train)
X2_test_scaled = scaler.transform(X2_test)

# Hyperparameter tuning
param_grid = {'C': [0.1, 1, 10, 100], 'gamma': [1, 0.1, 0.01, 0.001], 'epsilon': [0.1, 0.2, 0.3, 0.4]}
grid = GridSearchCV(SVR(kernel='linear'), param_grid, refit=True, verbose=3)
grid.fit(X2_train_scaled, Y2_train)
print(grid.best_params_)

# Optimized SVR
optimized_svr = SVR(kernel='linear', C=100, gamma=0.01, epsilon=0.1)
optimized_svr.fit(X2_train_scaled, Y2_train)

# Make predictions on the test set
y2_pred_optimized = optimized_svr.predict(X2_test_scaled)

# Calculate Mean Squared Error and R-squared for the optimized model
mse_optimized = mean_squared_error(Y2_test, y2_pred_optimized)
r2_optimized = r2_score(Y2_test, y2_pred_optimized)
print(f'Optimized Model - Mean Squared Error: {mse_optimized}')
print('Optimized Model - R-squared:', r2_optimized)

# Visualize Predictions
plt.scatter(Y2_test, y2_pred_optimized, color='red')
plt.plot([min(Y2_test), max(Y2_test)], [min(Y2_test), max(Y2_test)], color='blue', linestyle='--')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions (Optimized SVR)')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt

# Load the dataset
dataset_path = r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx'
df = pd.read_excel(dataset_path)

# Assuming that your dataset has features and target variable columns
# Replace 'feature_columns' and 'target_column' with your actual column names
feature_columns = df.drop('target_column', axis=1)
target_column = df['target_column']

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(feature_columns, target_column, test_size=0.2, random_state=42)

# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the SVR model
svr_model = SVR(kernel='linear')  # You can choose a different kernel if needed (e.g., 'rbf', 'poly')
svr_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = svr_model.predict(X_test_scaled)

# Evaluate the model
mse = mean_squared_error(y_test, y_pred)
print(f'Mean Squared Error: {mse}')

# Visualize the results (optional)
plt.scatter(X_test['Feature_of_Interest'], y_test, color='black', label='Actual data')
plt.scatter(X_test['Feature_of_Interest'], y_pred, color='blue', label='SVR Prediction')
plt.xlabel('Feature_of_Interest')
plt.ylabel('Target Variable')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14276\2053517655.py in <module>
#      12 # Assuming that your dataset has features and target variable columns
#      13 # Replace 'feature_columns' and 'target_column' with your actual column names
# ---> 14 feature_columns = df.drop('target_column', axis=1)
#      15 target_column = df['target_column']
#      16
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['target_column'] not found in axis"

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# One-hot encode categorical variables
encoder = OneHotEncoder()
encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

# Combine the encoded data with the original dataset
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder'], axis=1)
data2 = data2.join(encoded_data2)

# Convert feature names to strings
data2.columns = data2.columns.map(str)

# Assuming 'Farm Milk Production per \nDay' is the target variable
Y2_ = data2['Farm Milk Production per \nDay']
X2 = data2.drop(['Farm Milk Production per \nDay'], axis=1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X2, Y2_, test_size=0.1, random_state=42)


# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the Support Vector Regression (SVR) model with hyperparameter tuning
# Experiment with different kernels and hyperparameter values
svr_model = SVR(kernel='rbf', C=10, gamma='scale', epsilon=0.1)
svr_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = svr_model.predict(X_test_scaled)

# Calculate Root Mean Squared Error and R-squared
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(f'Root Mean Squared Error: {rmse}')
print('R-squared:', r2)

# Visualize the results (optional)
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions (SVR)')
plt.show()
# Out:
# Root Mean Squared Error: 25.869916375018324
# R-squared: 0.743570595024933

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVR
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# Load your dataset from Excel
data2 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Extrinsic Data.xlsx', sheet_name=0, usecols="B:P")

# One-hot encode categorical variables
encoder = OneHotEncoder()
encoded_data2 = pd.DataFrame(encoder.fit_transform(data2[['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder']]).toarray())

# Combine the encoded data with the original dataset
data2 = data2.drop(['Month', 'District', 'Zone', 'Green \nFodder', 'Dry\n Fodder'], axis=1)
data2 = data2.join(encoded_data2)

# Convert feature names to strings
data2.columns = data2.columns.map(str)

# Assuming 'Farm Milk Production per \nDay' is the target variable
Y2_ = data2['Farm Milk Production per \nDay']
X2 = data2.drop(['Farm Milk Production per \nDay'], axis=1)

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X2, Y2_, test_size=0.01, random_state=42)

# Feature Scaling
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Create and train the Support Vector Regression (SVR) model with hyperparameter tuning
# Experiment with different kernels and hyperparameter values
svr_model = SVR(kernel='rbf', C=10, gamma='scale', epsilon=0.1)
# svr_model = SVR(kernel='rbf', C=10, gamma=0.01, epsilon=0.1)

svr_model.fit(X_train_scaled, y_train)

# Make predictions on the test set
y_pred = svr_model.predict(X_test_scaled)

# Calculate Root Mean Squared Error and R-squared
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
r2 = r2_score(y_test, y_pred)
print(f'Root Mean Squared Error: {rmse}')
print('R-squared:', r2)

# Visualize the results (optional)
plt.scatter(y_test, y_pred, color='blue')
plt.plot([min(y_test), max(y_test)], [min(y_test), max(y_test)], linestyle='--', color='red')
plt.xlabel('True Values')
plt.ylabel('Predictions')
plt.title('True Values vs. Predictions (SVR)')
plt.show()
# Out:
# Root Mean Squared Error: 16.086996430096615
# R-squared: 0.8962726097103582

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.svm import SVR
from sklearn.metrics import mean_squared_error, r2_score

# Load data
data1 = pd.read_excel(r'C:\Users\user\Music\CP302-main1\Processed Data\Intrinsic Data.xlsx', sheet_name=0, usecols="B:E,H:I")

# One-hot encoding for categorical variable
encoder = OneHotEncoder()
encoded_data1 = pd.DataFrame(encoder.fit_transform(data1[['Breed']]).toarray())

# Separate target variable
Y1_ = data1['Milk Production/Day']
data1 = data1.drop(['Breed','Milk Production/Day'], axis=1)

# Combine encoded data and target variable
data1 = data1.join(encoded_data1)
data1 = data1.join(Y1_)

# Convert to numpy arrays
data1 = data1.to_numpy()
X1 = data1[:,0:-1]
Y1 = data1[:,-1]

# Split data into train and test sets
X1_train, X1_test, Y1_train, Y1_test = train_test_split(X1, Y1, test_size=0.2, random_state=0)

# Support Vector Machine Regression
svm_regressor = SVR(kernel='rbf')
svm_regressor.fit(X1_train, Y1_train)
y_pred_svm = svm_regressor.predict(X1_test)

# Model evaluation
r_squared_svm = r2_score(Y1_test, y_pred_svm)
mse_svm = mean_squared_error(Y1_test, y_pred_svm)
rmse_svm = np.sqrt(mse_svm)
print("R^2 score (Support Vector Machine Regression):", r_squared_svm)
print("Mean Squared Error (Support Vector Machine Regression):", mse_svm)
print("Root Mean Squared Error (Support Vector Machine Regression):", rmse_svm)

# Visualization
plt.figure(figsize=(10, 6))

# Scatter plot of actual vs predicted
plt.scatter(Y1_test, y_pred_svm, color='blue')
plt.plot(Y1_test, Y1_test, color='red', linestyle='--')
plt.title('Actual vs Predicted (Support Vector Machine Regression)')
plt.xlabel('Actual')
plt.ylabel('Predicted')
plt.grid(True)
plt.show()
# Out:
# C:\Users\user\anaconda3\lib\site-packages\scipy\__init__.py:155: UserWarning: A NumPy version >=1.18.5 and <1.25.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# R^2 score (Support Vector Machine Regression): 0.05646880724790315
# Mean Squared Error (Support Vector Machine Regression): 21.34813264411166
# Root Mean Squared Error (Support Vector Machine Regression): 4.620403948153415
